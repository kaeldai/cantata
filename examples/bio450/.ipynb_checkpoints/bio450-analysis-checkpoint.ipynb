# %%
import polars as pl
import matplotlib.pyplot as plt

# %%
df = pl.read_csv('out/spikes.csv')

# %%
fg, ax = plt.subplots()
ax.scatter(df['time:'], df['gid'])

# %%
df.head()
# Out:
# shape: (5, 3)
# ┌───────┬────────┬────────┐
# │ time: ┆ gid    ┆ lid    │
# │ ---   ┆ ---    ┆ ---    │
# │ f64   ┆ str    ┆ str    │
# ╞═══════╪════════╪════════╡
# │ 6.049 ┆    519 ┆      0 │
# │ 8.049 ┆    320 ┆      0 │
# │ 8.049 ┆    367 ┆      0 │
# │ 8.049 ┆    377 ┆      0 │
# │ 8.049 ┆    384 ┆      0 │
# └───────┴────────┴────────┘
